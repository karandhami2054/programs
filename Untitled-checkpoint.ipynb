# %%
print("Create your own mad Libs game:")
# Out:
# Create your own mad Libs game:

# %%
print("The program should generate a fun and unique story based on the user's input: ")
print("Please input the following:")
noun = input("Enter the noun: ")
verb = input("Enter the verb: ")
adjective = input("Enter the adjective: ")
adverbb = input("Enter thead verb: ")
place = input("Enter where do you live: "))
# Out:
#   Cell In[10], line 7
#     place = input("Enter where do you live: "))
#                                               ^
# SyntaxError: unmatched ')'

# %%
print("Once upon a time, there was a very", adjective, noun)
print(f"i loved to {verb} {adverb} everyday in {place}")
