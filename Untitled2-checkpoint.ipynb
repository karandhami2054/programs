# %%
print("***Library Management System***")
name = input("Enter student's name: ")
student_id = int(input("Enter student's ID: "))
book_name = input("Enter book name you want: ")
days = int(input("How long do you want to take the book in days: "))
price = float(input("Enter price of book: "))
# Out:
# ***Library Management System***
# Enter student's name:  karan
# Enter student's ID:  121
# Enter book name you want:  python basics
# How long do you want to take the book in days:  5
# Enter price of book:  1000

# %%
print("Borrowing student's details:")
print("Student Name: ", name) 
print("Student ID: ", student_id)
print("Book Name: ", book_name)
print("Book Price: ",price)
print("Book Borrowing Days: ", days)
library_fee = 50

print(f'Library fee: {library_fee} \nTotal Amount = NPR {library_fee + price}')
# Out:
# Borrowing student's details:
# Student Name:  karan
# Student ID:  121
# Book Name:  python basics
# Book Price:  1000.0
# Book Borrowing Days:  5
# Library fee: 50
# Total Amount = NPR 1050.0
